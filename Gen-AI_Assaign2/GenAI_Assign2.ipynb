# %%
# Module 1: Environment Setup
# !pip install -q langchain-groq groq
print("✅ Libraries installed.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 5.7 MB/s eta 0:00:00
# ✅ Libraries installed.

# %%
# Module 2: Authentication
from google.colab import userdata
import os

try:
    os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
    print("✅ API Key loaded from Colab Secrets.")
except Exception:
    print("❌ Error: Please add GROQ_API_KEY to the Secrets tab.")
# Out:
# ✅ API Key loaded from Colab Secrets.

# %%
# Module 3: Logic Definition
from groq import Groq
from IPython.display import display, Markdown

class ColabChatbot:
    def __init__(self, model="llama-3.3-70b-versatile"):
        self.client = Groq(api_key=os.environ.get("GROQ_API_KEY"))
        self.model = model

    def ask(self, question):
        completion = self.client.chat.completions.create(
            model=self.model,
            messages=[
                {"role": "system", "content": "You are a helpful AI assistant. Format your answers using Markdown."},
                {"role": "user", "content": question}
            ],
            temperature=0.3
        )
        return completion.choices[0].message.content

# %%
# Module 4: Interaction
bot = ColabChatbot()

print("🤖 Chatbot Active (type 'exit' to stop)")
while True:
    query = input("\nUser: ")
    if query.lower() in ['exit', 'quit']:
        print("Bot: Goodbye!")
        break

    response = bot.ask(query)
    display(Markdown(f"**Bot:** {response}"))
# Out:
# 🤖 Chatbot Active (type 'exit' to stop)
#
# User: Explain the difference between a Decoder-only and an Encoder-Decoder architecture in Transformers
# **Bot:** ### Introduction to Transformer Architectures
# Transformer models are a type of neural network architecture introduced in the paper "Attention Is All You Need" by Vaswani et al. in 2017. They revolutionized the field of natural language processing (NLP) and have been widely adopted for various tasks such as language translation, text generation, and question answering.
#
# ### Encoder-Decoder Architecture
# The Encoder-Decoder architecture is the original Transformer model proposed by Vaswani et al. It consists of two main components:
# * **Encoder**: The encoder takes in a sequence of tokens (e.g., words or characters) and outputs a sequence of vectors. The encoder is composed of a stack of identical layers, each consisting of two sub-layers: self-attention and feed-forward neural network (FFNN).
# ...
